# %%
from sklearn.datasets import load_iris
iris = load_iris()


X = iris.data
y = iris.target
from sklearn import preprocessing
normalized_x = preprocessing.normalize(X)
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
X_train, X_test, y_train, y_test = train_test_split(normalized_x, y, test_size=0.4, random_state=4)
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)
print(metrics.accuracy_score(y_test, y_pred))
from sklearn.metrics import confusion_matrix,classification_report
print(confusion_matrix(y_test,y_pred,))
print(classification_report(y_test,y_pred))
# Out:
# 0.95
# [[25  0  0]
#  [ 0 15  2]
#  [ 0  1 17]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        25
#            1       0.94      0.88      0.91        17
#            2       0.89      0.94      0.92        18
#
#     accuracy                           0.95        60
#    macro avg       0.94      0.94      0.94        60
# weighted avg       0.95      0.95      0.95        60

# %%
k_range = range(1, 26)

# We can create Python dictionary using [] or dict()
scores = []

# We use a loop through the range 1 to 26
# We append the scores in the dictionary
for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    scores.append(metrics.accuracy_score(y_test, y_pred))

print(scores)
# import Matplotlib (scientific plotting library)
import matplotlib.pyplot as plt

# allow plots to appear within the notebook
# %matplotlib inline

# plot the relationship between K and testing accuracy
# plt.plot(x_axis, y_axis)
plt.plot(k_range, scores)
plt.xlabel('Value of K for KNN')
plt.ylabel('Testing Accuracy')
# Out:
# [0.9833333333333333, 0.95, 0.9833333333333333, 0.9666666666666667, 0.95, 0.9666666666666667, 0.95, 0.9666666666666667, 0.9666666666666667, 0.9833333333333333, 0.9833333333333333, 0.9833333333333333, 0.9666666666666667, 0.9833333333333333, 0.9833333333333333, 0.9833333333333333, 0.9666666666666667, 0.9666666666666667, 0.9666666666666667, 0.9666666666666667, 0.9666666666666667, 0.9666666666666667, 0.9666666666666667, 0.9666666666666667, 0.9666666666666667]
# Text(0, 0.5, 'Testing Accuracy')

# %%
import pandas as pd
dataset = pd.read_csv(r"C:\Users\TOTO\Documents\diabetes (1).csv")

# create X (features) and y (response)
X = dataset.iloc[:,0:-1]
y = dataset.iloc[:,-1]
from sklearn import preprocessing
normalized_x = preprocessing.normalize(X)
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
X_train, X_test, y_train, y_test = train_test_split(normalized_x, y, test_size=0.4, random_state=4)
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)
print(metrics.accuracy_score(y_test, y_pred))
from sklearn.metrics import confusion_matrix,classification_report
print(confusion_matrix(y_test,y_pred,))
print(classification_report(y_test,y_pred))
# Out:
# 0.6948051948051948
# [[162  44]
#  [ 50  52]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.79      0.78       206
#            1       0.54      0.51      0.53       102
#
#     accuracy                           0.69       308
#    macro avg       0.65      0.65      0.65       308
# weighted avg       0.69      0.69      0.69       308

# %%
k_range = range(1, 26)

# We can create Python dictionary using [] or dict()
scores = []

# We use a loop through the range 1 to 26
# We append the scores in the dictionary
for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    scores.append(metrics.accuracy_score(y_test, y_pred))

print(scores)
# import Matplotlib (scientific plotting library)
import matplotlib.pyplot as plt

# allow plots to appear within the notebook
# %matplotlib inline

# plot the relationship between K and testing accuracy
# plt.plot(x_axis, y_axis)
plt.plot(k_range, scores)
plt.xlabel('Value of K for KNN')
plt.ylabel('Testing Accuracy')
# Out:
# [0.6168831168831169, 0.6525974025974026, 0.6558441558441559, 0.6785714285714286, 0.6948051948051948, 0.6785714285714286, 0.6688311688311688, 0.6525974025974026, 0.6558441558441559, 0.672077922077922, 0.6558441558441559, 0.6623376623376623, 0.6623376623376623, 0.6915584415584416, 0.6785714285714286, 0.672077922077922, 0.672077922077922, 0.6785714285714286, 0.672077922077922, 0.6818181818181818, 0.6753246753246753, 0.685064935064935, 0.672077922077922, 0.6753246753246753, 0.6590909090909091]
# Text(0, 0.5, 'Testing Accuracy')
